# %% [markdown]
# # Challenge 1

# %%
import pandas as pd
import unicodedata

# %%
ch_1=pd.read_csv('../data/input/IMDB-Movie-Data.csv')
ch_1
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
def votes(x):
    if 0 <= x <= 999:
        return 1
    elif 1000<=x<=9999:
        return 2
    elif 10000<=x<=99999:
        return 3
    elif 100000<=x<=999999:
        return 4
    elif x>=1000000:
        return 5

# %%
ch_1['Bin'] = ch_1['Votes'].apply(votes)
ch_1.head(1)
# Out:
#    Rank                    Title                    Genre  \
# 0     1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating   Votes  Revenue (Millions)  Metascore  Bin
# 0     8.1  757074              333.13       76.0    4

# %%
ch_1['Bin'] = ch_1.apply(lambda angel : votes(angel['Votes']), axis=1)
ch_1.head(1)
# Out:
#    Rank                    Title                    Genre  \
# 0     1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating   Votes  Revenue (Millions)  Metascore  Bin
# 0     8.1  757074              333.13       76.0    4

# %%
var = lambda x : x + 2

# %%
var(5)
# Out:
# 7

# %% [markdown]
# ### Challenge 2

# %%
ch_1.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'Bin'],
#       dtype='object')

# %%
ch_1['revenue/minute'] = ch_1['Revenue (Millions)'] / ch_1['Runtime (Minutes)']
ch_1.head(1)
# Out:
#    Rank                    Title                    Genre  \
# 0     1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating   Votes  Revenue (Millions)  Metascore  Bin  revenue/minute
# 0     8.1  757074              333.13       76.0    4         2.75314

# %%
def revenue(x,y):
    return x/y

# %%
ch_1['revenue/minutes'] = ch_1.apply(lambda angel : revenue(angel['Revenue (Millions)'], angel['Runtime (Minutes)']), axis=1)
ch_1.head(1)
# Out:
#    Rank                    Title                    Genre  \
# 0     1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating   Votes  Revenue (Millions)  Metascore  Bin  revenue/minute  \
# 0     8.1  757074              333.13       76.0    4         2.75314
#
#    revenue/minutes
# 0          2.75314

# %% [markdown]
# ### Challenge 3

# %%
ch_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
#  12  Bin                 1000 non-null   int64
#  13  revenue/minute      872 non-null    float64
#  14  revenue/minutes     872 non-null    float64
# ...

# %%
ch_1['Genre'].unique()
# Out:
# array(['Action,Adventure,Sci-Fi', 'Adventure,Mystery,Sci-Fi',
#        'Horror,Thriller', 'Animation,Comedy,Family',
#        'Action,Adventure,Fantasy', 'Comedy,Drama,Music', 'Comedy',
#        'Action,Adventure,Biography', 'Adventure,Drama,Romance',
#        'Adventure,Family,Fantasy', 'Biography,Drama,History',
#        'Animation,Adventure,Comedy', 'Action,Comedy,Drama',
#        'Action,Thriller', 'Biography,Drama', 'Drama,Mystery,Sci-Fi',
#        'Adventure,Drama,Thriller', 'Drama', 'Crime,Drama,Horror',
#        'Action,Adventure,Drama', 'Drama,Thriller',
#        'Action,Adventure,Comedy', 'Action,Horror,Sci-Fi',
#        'Adventure,Drama,Sci-Fi', 'Action,Adventure,Western',
#        'Comedy,Drama', 'Horror', 'Adventure,Drama,Fantasy',
#        'Action,Crime,Thriller', 'Action,Crime,Drama',
#        'Adventure,Drama,History', 'Crime,Horror,Thriller',
#        'Drama,Romance', 'Comedy,Drama,Romance', 'Horror,Mystery,Thriller',
# ...

# %%
def new_rk(rk,gen):
    if 'Thriller' in gen:
        return rk + 1
    elif 'Comedy' in gen:
        return rk - 1
    else:
        return rk

# %%
ch_1['new'] = ch_1.apply(lambda angel : new_rk(angel['Rank'], angel['Genre']), axis=1)
ch_1.head(5)
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %% [markdown]
# # Challenge 4

# %%
ch_1['Title ASCII'] = sum(ch_1['Title'].str.len())
ch_1.head(1)
# Out:
#    Rank                    Title                    Genre  \
# 0     1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating   Votes  Revenue (Millions)  Metascore  Bin  revenue/minute  \
# 0     8.1  757074              333.13       76.0    4         2.75314
#
#    revenue/minutes       new    len    recount  Title ASCII
# 0          2.75314  0.000001  14539  52.071944        14539

# %%
ch_1['Title ASCII'] =  ch_1['Title ASCII'].apply(lambda angel: unicodedata.normalize('NFKD', angel).encode('ascii', 'ignore').decode())
ch_1.head(1)
sum(ch_1['Title ASCII'].str.len())
# Out:
#    Rank                    Title                    Genre  \
# 0     1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating   Votes  Revenue (Millions)  Metascore  Bin  revenue/minute  \
# 0     8.1  757074              333.13       76.0    4         2.75314
#
#    revenue/minutes       new    len    recount              Title ASCII
# 0          2.75314  0.000001  14539  52.071944  Guardians of the Galaxy

# %%
ch_1['Title ASCII count'] = sum(ch_1['Title'].str.len())
ch_1.head(1)
# Out:
#    Rank                    Title                    Genre  \
# 0     1  Guardians of the Galaxy  Action,Adventure,Sci-Fi
#
#                                          Description    Director  \
# 0  A group of intergalactic criminals are forced ...  James Gunn
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
#
#    Rating   Votes  Revenue (Millions)  Metascore  Bin  revenue/minute  \
# 0     8.1  757074              333.13       76.0    4         2.75314
#
#    revenue/minutes       new    len    recount              Title ASCII  \
# 0          2.75314  0.000001  14539  52.071944  Guardians of the Galaxy
#
#    Title ASCII count
# 0              14539

# %%
ch_1['Votes']/ch_1['Title ASCII count']
# Out:
# 0      52.071944
# 1      33.414953
# 2      10.840223
# 3       4.164317
# 4      27.080748
#          ...
# 995     1.897311
# 996     5.031433
# 997     4.862714
# 998     0.335718
# 999     0.855286
# Length: 1000, dtype: float64

# %%
# No son integers, por tanto tampoco números primos.

# %% [markdown]
# # Challenge 5

# %%
ch_1.sort_values (by = ['Year', 'Rating', 'Votes'], ascending = (True))
# Out:
#      Rank                                  Title                    Genre  \
# 773   774                      Lady in the Water    Drama,Fantasy,Mystery
# 901   902                      Snakes on a Plane   Action,Adventure,Crime
# 550   551                           The Break-Up     Comedy,Drama,Romance
# 308   309  The Fast and the Furious: Tokyo Drift    Action,Crime,Thriller
# 924   925                       Superman Returns  Action,Adventure,Sci-Fi
# ..    ...                                    ...                      ...
# 478   479                         Paint It Black                    Drama
# 6       7                             La La Land       Comedy,Drama,Music
# 861   862                         Koe no katachi  Animation,Drama,Romance
# 96     97                          Kimi no na wa  Animation,Drama,Fantasy
# 117   118                                 Dangal   Action,Biography,Drama
#
#                                            Description            Director  \
# ...
